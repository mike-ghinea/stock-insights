# %% [markdown]
# # Tesla Stock Analysis
# ### Investing 100$ every week for the past 5 years, at the closing price
# #### Data accurate as of 13/04/2020
# ##### With dedication to one Dickson Dokowe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tesla_data = pd.read_csv("TSLA_data.csv")  # Stock data for Tesla from the past 5 years

# %%
plt.figure(figsize=(20, 10))
plt.xlabel("Date")
plt.ylabel("Price")
plt.plot(tesla_data["Date"], tesla_data["Close"])

# %%
weeks = math.floor(len(tesla_data) / 7)

# %%
buy_dates = []
for week in range(weeks + 1):
    buy_dates.append(tesla_data["Date"][week * 7])

# %%
buy_days = tesla_data[tesla_data["Date"].isin(buy_dates)]

# %%
plt.figure(figsize=(20, 10))
plt.xlabel("Date")
plt.ylabel("Price")
plt.plot(buy_dates, buy_days["Close"])

# %%
stock_amount = sum([100 / price for price in buy_days["Close"]])
investment_amount = 100 * weeks
profit = (stock_amount * tesla_data["Close"][1258] - investment_amount) / investment_amount * 100

# %%
print(f"After {weeks} weeks, you'd have owned {stock_amount} stock units and invested ${investment_amount}")
print(f"For a profit of {profit}%")
# Out:
# After 179 weeks, you'd have owned 67.00969916409868 stock units and invested $17900
# For a profit of 143.6869524517292%
